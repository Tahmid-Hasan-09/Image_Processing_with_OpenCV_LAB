# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Image Read

# %% [markdown]
# ## Show BGR Image

# %%
img_bgr = cv2.imread('DATA/00-puppy.jpg')
plt.imshow(img_bgr)

# %% [markdown]
# ## Convert to RGB Image

# %%
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %% [markdown]
# ## Convert to Grayscale Image

# %%
img_gray = cv2.imread('DATA/00-puppy.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %% [markdown]
# ## Accurate Grayscale Image

# %%
img_gray = cv2.imread('DATA/00-puppy.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray,cmap='gray')

# %% [markdown]
# # Resize Images

# %%
img = cv2.imread('DATA/00-puppy.jpg')

# %%
img =cv2.resize(img,(1300,275),interpolation=cv2.INTER_AREA)

# %%
plt.imshow(img)

# %%
#resizing
img = cv2.imread('DATA/00-puppy.jpg')
resized_img=cv2.resize(img,(300,300),interpolation=cv2.INTER_AREA)

cv2.imshow('Resized image',resized_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## By ratio

# %%
w_ratio = 0.5
h_ratio = 0.5
new_img =cv2.resize(img_rgb,(0,0),img,w_ratio,h_ratio)
plt.imshow(new_img)

# %% [markdown]
# # Flipping Images

# %%
# Along central x axis
img = cv2.imread('DATA/00-puppy.jpg')
new_img = cv2.flip(img,0)
plt.imshow(new_img)

# %%
# Along both axis
new_img = cv2.flip(img,-1)
plt.imshow(new_img)

# %%
#flipping
img = cv2.imread('DATA/00-puppy.jpg')
flipped_img=cv2.flip(img,1)#flip code=1/-1/0

cv2.imshow('flipped image',flipped_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img=cv2.imread('./images/flemingo.jpg')

# %%
#rotation
def rotate(img,angle,rotPoint=None):
    (height,width) = img.shape[:2]
        
    if rotPoint is None:
        rotPoint=(width//2,height//2)

    rotation_matrix=cv2.getRotationMatrix2D(rotPoint,angle,1) 
    dimensions = (width,height)
    rotated_img=cv2.warpAffine(img,rotation_matrix,dimensions)
    return rotated_img

rotated_img = rotate(img,45)
cv2.imshow('Rotated image',rotated_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#translation(shifting)
def translate(img,Tx,Ty):
    height= img.shape[0]
    width = img.shape[1]

#     |1 0 Tx |     Translation matrix
# T = |0 1 Ty |

    transMat= np.float32([[1,0,Tx],
               [0,1,Ty]])
    img_translation = cv2.warpAffine(img,transMat,(width,height))
    return img_translation

img_translation = translate(img,100,100)

cv2.imshow('Original Image',img)
cv2.imshow('Translation',img_translation)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#translation(shifting)
tx=100
ty=150
m=np.float32([[1,0,tx],[0,1,ty]])
shifted_image=cv2.warpAffine(img,m,(img.shape[1],img.shape[0]))

cv2.imshow('Shifted image',shifted_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#cropping 
height,width = img.shape[:2]
#Starting Pixel coordinates(top left,of croping rectangle)
start_row,start_col = int(height*.25),int(width*.25)
#Ebding Pixel coordinates(bottom right)
end_row,end_col = int(height*.75),int(width*.75)
cropped = img[start_row:end_row,start_col:end_col]
cv2.imshow('Original Image',img)
cv2.imshow('Cropped',cropped)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#cropping 
cropped_img=img[0:100,100:400]

cv2.imshow('cropped image',cropped_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
